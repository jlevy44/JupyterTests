:0.00034553)100:0.00041439,Spa-Sou-AB3.3:0.0014642080)55:0.00032912)56:0.00029337,Spa-Sou-CU1.6-1:0.0014116070)100:0.00168983,Bd18-1:0.0014906975)100:0.00025360,(Arm-Arm3i:0.0010370495,(((((Geo-G34i2:0.0000006441,Geo-G34i6:0.0000009810)100:0.00023179,(Arm-Arm3G:0.0000002833,Arm-Arm3A:0.0000006441)100:0.00070773)100:0.00076690,Geo-G31i4:0.0008018189)83:0.00030809,Geo-G32i2:0.0003947833)100:0.00061709,Arm-Arm2B:0.0007875003)83:0.00033901)100:0.00090613)100:0.00043351,((Gaz-1:0.0006851168,(BdTR2B:0.0004455889,BdTR1i:0.0001679142)100:0.00123820)100:0.00060103,(Gaz-7:0.0002059119,Gaz-2:0.0001266270)100:0.00121087)100:0.00042416)100:0.00033554,Koz-3:0.0033619970)100:0.00020355)100:0.00034323,((BdTR13B:0.0000038873,BdTR13a:0.0000013064)56:0.00000028,((Bis-1:0.0016235249,BdTR13C:0.0017627163)100:0.00025557,BdTR13N:0.0000031440)61:0.00000028)100:0.00133521)49:0.00026882,(Kah-6:0.0014486002,Kah-5:0.0012722437)45:0.00031267)78:0.00023859,Adi-9:0.0014855754)83:0.00027618,((BdTR12B:0.0000003592,BdTR12c:0.0017630368)100:0.00073804,((BdTR9M:0.0005319875,Adi-12:0.0014022039)100:0.00057510,Adi-2:0.0013681118)92:0.00033140)92:0.00040693)75:0.00016829,(Adi-15:0.0005582778,(BdTR11I:0.0000594339,BdTR11G:0.0003610023)100:0.00058179)100:0.00083062)73:0.00040340,BdTR10D:0.0011471293)100:0.00082264,Bd2-3:0.0034981224)100:0.00053764,(Bd21-3_r:0.0000052864,Vasc1:0.0000057284)100:0.00119855)100:0.00094853,(Bdistachyon:0.0000012556,Bd21Control:0.0000768157)100:0.00103927)100:0.00455904)100:0.00151405,(Ita-Sic-LPA3.2:0.0014257726,Ita-Sic-CSR-6:0.0012899703)100:0.00596620)100:0.00680948)100:0.01889115,Bhybridum118-5D:0.0019874042);"

# %%
t = Tree(tree)
ts = TreeStyle()

# %%
#nstyle = NodeStyle()
#nstyle.size = 0
#t.set_style(nstyle)
for n in t.traverse():
    n.img_style['size']=0

# %%
ts.show_branch_support = True
R = t.get_midpoint_outgroup()
t.set_outgroup(R)
t.img_style['size']=0
ts.show_leaf_name= True
for n in t.traverse():
    n.img_style['size']=0

# %%
t.render('110_final_tree_100_bootstrap.png',dpi=300,w=1000,tree_style=ts)
# Out:
# {'faces': [[1.8111279935405264,
#    1207.0507161041867,
#    10.86676796124316,
#    1223.3508680460513,
#    0,
#    '1'],
#   [280.97861822159774,
#    144.6072507342514,
#    306.3344101311651,
#    160.90740267611613,
#    1,
#    '100'],
#   [306.3344101311651,
#    113.53508609507175,
#    331.69020204073246,
#    129.8352380369365,
#    2,
#    '100'],
#   [331.69020204073246,
#    83.99106070044192,
#    357.0459939502998,
#    100.29121264230665,
#    3,
#    '100'],
#   [357.0459939502998,
#    46.636545833668556,
#    373.34614589216454,
#    62.9366977755333,
#    4,
#    '99'],
#   [374.0656871113662,
#    1.8111279935405264,
#    428.39952691758197,
#    23.544663916026845,
#    5,
#    'Bd28S'],
#   [373.34614589216454,
#    80.59519571255343,
#    389.6462978340293,
#    96.89534765441816,
#    6,
#    '99'],
#   [389.6462978340293,
#    61.5783517803779,
#    405.94644977589405,
#    77.87850372224264,
#    7,
#    '97'],
#   [405.94644977589405,
# ...

# %%
t.show()

# %%
with open('final_tree_TN+F+ASC+R6.treefile','w') as f:
    f.write(tree)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-080b54dcf029> in <module>()
# ----> 1 nstyle = NodeStyle()
#
# NameError: name 'NodeStyle' is not defined
