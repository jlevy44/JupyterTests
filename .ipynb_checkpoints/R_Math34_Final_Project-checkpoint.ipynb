# %%
install.packages('ggplot2')
library(ggplot2)
# Out:
# The downloaded binary packages are in
# 	/var/folders/mj/jyvlrh717hdgms0mf1vy_8g80000gn/T//RtmpoOBgkC/downloaded_packages

# %%
data = read.csv('classifier_accuracy_out.csv')

# %%
data
# Out:
#     Nearest.Neighbors Neural.Network Pairwise.Accuracy.Differences
# 1   88                88              0
# 2   79                81             -2
# 3   79                80             -1
# 4   82                82              0
# 5   89                85              4
# 6   86                82              4
# 7   84                92             -8
# 8   91                87              4
# 9   81                87             -6
# 10  87                85              2
# 11  84                90             -6
# 12  84                84              0
# 13  83                80              3
# 14  89                85              4
# 15  91                89              2
# 16  86                81              5
# 17  85                87             -2
# 18  88                82              6
# 19  84                87             -3
# 20  81                83             -2
# 21  89                85              4
# 22  82                86             -4
# 23  83                89             -6
# 24  80                80              0
# 25  83                84             -1
# 26  81                78              3
# 27  85                87             -2
# 28  82                90             -8
# 29  87                86              1
# 30  82                85             -3
# ⋮   ⋮                 ⋮              ⋮
# 71  85                83              2
# 72  86                86              0
# 73  80                82             -2
# 74  81                83             -2
# 75  79                85             -6
# 76  84                87             -3
# 77  85                87             -2
# 78  85                90             -5
# 79  85                87             -2
# 80  87                83              4
# 81  87                88             -1
# 82  87                87              0
# 83  83                81              2
# 84  84                92             -8
# 85  85                86             -1
# 86  86                85              1
# 87  79                81             -2
# 88  83                81              2
# 89  91                85              6
# 90  84                80              4
# 91  88                87              1
# 92  85                87             -2
# 93  79                81             -2
# 94  83                81              2
# 95  79                79              0
# 96  76                82             -6
# 97  90                93             -3
# 98  79                87             -8
# 99  85                88             -3
# 100 89                89              0

# %%
#install.packages('reshape2')
#library(reshape2)
melt(data[1:2])
# Out:
# No id variables; using all as measure variables
#     variable          value
# 1   Nearest.Neighbors 88
# 2   Nearest.Neighbors 79
# 3   Nearest.Neighbors 79
# 4   Nearest.Neighbors 82
# 5   Nearest.Neighbors 89
# 6   Nearest.Neighbors 86
# 7   Nearest.Neighbors 84
# 8   Nearest.Neighbors 91
# 9   Nearest.Neighbors 81
# 10  Nearest.Neighbors 87
# 11  Nearest.Neighbors 84
# 12  Nearest.Neighbors 84
# 13  Nearest.Neighbors 83
# 14  Nearest.Neighbors 89
# 15  Nearest.Neighbors 91
# 16  Nearest.Neighbors 86
# 17  Nearest.Neighbors 85
# 18  Nearest.Neighbors 88
# 19  Nearest.Neighbors 84
# 20  Nearest.Neighbors 81
# 21  Nearest.Neighbors 89
# 22  Nearest.Neighbors 82
# 23  Nearest.Neighbors 83
# 24  Nearest.Neighbors 80
# 25  Nearest.Neighbors 83
# 26  Nearest.Neighbors 81
# 27  Nearest.Neighbors 85
# 28  Nearest.Neighbors 82
# 29  Nearest.Neighbors 87
# 30  Nearest.Neighbors 82
# ⋮   ⋮                 ⋮
# 171 Neural.Network    83
# 172 Neural.Network    86
# 173 Neural.Network    82
# 174 Neural.Network    83
# 175 Neural.Network    85
# 176 Neural.Network    87
# 177 Neural.Network    87
# 178 Neural.Network    90
# 179 Neural.Network    87
# 180 Neural.Network    83
# 181 Neural.Network    88
# 182 Neural.Network    87
# 183 Neural.Network    81
# 184 Neural.Network    92
# 185 Neural.Network    86
# 186 Neural.Network    85
# 187 Neural.Network    81
# 188 Neural.Network    81
# 189 Neural.Network    85
# 190 Neural.Network    80
# 191 Neural.Network    87
# 192 Neural.Network    87
# 193 Neural.Network    81
# 194 Neural.Network    81
# 195 Neural.Network    79
# 196 Neural.Network    82
# 197 Neural.Network    93
# 198 Neural.Network    87
# 199 Neural.Network    88
# 200 Neural.Network    89

# %%
qplot(data$Pairwise.Accuracy.Differences,binwidth=3)
#qplot('',data$Pairwise.Accuracy.Differences,data=data$Pairwise.Accuracy.Differences,'boxplot')
long = melt(data[1:2])
ggplot(long, aes(factor(long[, 1]), long[, 2])) + geom_boxplot(fill=c('red','blue'))#qplot(y=c(data$Nearest.Neighbors,data$Neural.Network),x=c("Nearest Neighbors","Neural Network"),geom='boxplot',fill=c('r','b'))
qplot(y=data$Pairwise.Accuracy.Differences,x="Pairwise Differences",geom='boxplot',fill='r')
summary(data$Pairwise.Accuracy.Differences)
# Out:
# No id variables; using all as measure variables
# plot without title
# plot without title
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   -8.00   -3.00   -1.00   -0.77    2.00   10.00
# plot without title

# %%
t.test(data$Pairwise.Accuracy.Differences,alternative='less')
# Out:
# 	One Sample t-test
#
# data:  data$Pairwise.Accuracy.Differences
# t = -1.9718, df = 99, p-value = 0.02571
# alternative hypothesis: true mean is less than 0
# 95 percent confidence interval:
#        -Inf -0.1216051
# sample estimates:
# mean of x
#     -0.77

# %%
# change prompt to neural network (with standard scaling) is more accurate than nearest neighbors algorithm
